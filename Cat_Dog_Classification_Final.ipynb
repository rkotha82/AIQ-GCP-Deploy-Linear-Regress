# %% [markdown]
# <a href="https://colab.research.google.com/github/rkotha82/AIQ-GCP-Deploy-Linear-Regress/blob/master/Cat_Dog_Classification_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# classification refers to a predictive modeling problem where a class label is predicted for a given example of input data. Examples of classification problems include: Given an example, classify if it is spam or not. Given a handwritten character, classify it as one of the known characters

# %% [markdown]
# ![1_ATIx1SmkEH0FaL_5fMvX2w.jpeg](data:image/jpeg;base64,...)

# %%
## to ignore all the warning 

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Step 1: Import the Data

# %%
# the data set is present in the drive in the zip format. 
# we will be using linix cammand to import our data set 
# !wget "https://www.dropbox.com/s/1k9me2n5ya1usqw/CatDogDataSet.zip?dl=0"
# Out:
# --2021-07-31 06:35:01--  https://www.dropbox.com/s/1k9me2n5ya1usqw/CatDogDataSet.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.18, 2620:100:6032:18::a27d:5212
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/1k9me2n5ya1usqw/CatDogDataSet.zip [following]
# --2021-07-31 06:35:01--  https://www.dropbox.com/s/raw/1k9me2n5ya1usqw/CatDogDataSet.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc33b9fe52f51830a20d387bd815.dl.dropboxusercontent.com/cd/0/inline/BTVwUNXwt9jGP2K5TOH1aGeKXpFEyPSpaEl3elMIb3uAk10NcMXkgWKh9qmhPhD082bPkLlDXHSqdr-PhfzxR9yG07xKLcRWjlLSE1-OBQu5sk2uu0fKbtzo5DEKyAfC2gDN8_tvryNkdTE5BEUokLiq/file# [following]
# --2021-07-31 06:35:01--  https://uc33b9fe52f51830a20d387bd815.dl.dropboxusercontent.com/cd/0/inline/BTVwUNXwt9jGP2K5TOH1aGeKXpFEyPSpaEl3elMIb3uAk10NcMXkgWKh9qmhPhD082bPkLlDXHSqdr-PhfzxR9yG07xKLcRWjlLSE1-OBQu5sk2uu0fKbtzo5DEKyAfC2gDN8_tvryNkdTE5BEUokLiq/file
# Resolving uc33b9fe52f51830a20d387bd815.dl.dropboxusercontent.com (uc33b9fe52f51830a20d387bd815.dl.dropboxusercontent.com)... 162.125.1.15, 2620:100:6016:15::a27d:10f
# Connecting to uc33b9fe52f51830a20d387bd815.dl.dropboxusercontent.com (uc33b9fe52f51830a20d387bd815.dl.dropboxusercontent.com)|162.125.1.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BTUiCaPS1ZnAjyKkDChFgSfKXiSeXl2V5m1xw3FbqYrQpYLTk3Rj3dw4cOf0SWLMflzuWocavinAql0hDvz8vyDR1Ec8eHx4eHn1n_ZZ8WwBhIgGjXWZQpyRc9-oMHBa-bhoxwO8CM9gDwwozBl2b627fYhhVKmmYwTtCRW3kOUtiYZxlhmLWodBWEL9TGd0pPPbTATw7E2CC9PO9r7QutrCb1DiBDTa6Gil_kSCfPrUoojrrZ7CAmFvFEA7NKB04sTsit9tSQWlcD1rOXYtiba0zliN6eurqxb8GypXLIO-cKJqtd73DJGCD95LoLI_5i2-B1CAhuqfCcrSciYTf-2yfb7ercFpyZbJNfrjW-lfeQgaffp9uTVtdIoitJ9asaQ/file [following]
# --2021-07-31 06:35:01--  https://uc33b9fe52f51830a20d387bd815.dl.dropboxusercontent.com/cd/0/inline2/BTUiCaPS1ZnAjyKkDChFgSfKXiSeXl2V5m1xw3FbqYrQpYLTk3Rj3dw4cOf0SWLMflzuWocavinAql0hDvz8vyDR1Ec8eHx4eHn1n_ZZ8WwBhIgGjXWZQpyRc9-oMHBa-bhoxwO8CM9gDwwozBl2b627fYhhVKmmYwTtCRW3kOUtiYZxlhmLWodBWEL9TGd0pPPbTATw7E2CC9PO9r7QutrCb1DiBDTa6Gil_kSCfPrUoojrrZ7CAmFvFEA7NKB04sTsit9tSQWlcD1rOXYtiba0zliN6eurqxb8GypXLIO-cKJqtd73DJGCD95LoLI_5i2-B1CAhuqfCcrSciYTf-2yfb7ercFpyZbJNfrjW-lfeQgaffp9uTVtdIoitJ9asaQ/file
# Reusing existing connection to uc33b9fe52f51830a20d387bd815.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 855802700 (816M) [application/zip]
# Saving to: ‘CatDogDataSet.zip’
#
# CatDogDataSet.zip   100%[===================>] 816.16M   109MB/s    in 7.9s
#
# 2021-07-31 06:35:10 (103 MB/s) - ‘CatDogDataSet.zip’ saved [855802700/855802700]

# %%
# In the next step we will unzip our data set using the linix command i.e "!unzip"

# !unzip "/content/CatDogDataSet.zip?dl=0"

# %%
# imports 

import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from skimage.io import imread, imshow
import shutil

import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Input, Conv2D, Flatten, Dense, Dropout, MaxPool2D
from keras.preprocessing.image import load_img, img_to_array

# %% [markdown]
# #Step 2: Data Visualization & Preprocessing

# %%
# now we will visualise and see how many images are there in our data set 
# this is a important step for data pre preocessing as it is essential to ensure our data is balanced 

TRAIN_DIR = "/content/Cat Dog Data Set/train" 

dict = {'cat':0 , 'dog': 0}

for dir in os.listdir(TRAIN_DIR):
  path = os.path.join(TRAIN_DIR, dir)
  dict[dir] = len(os.listdir(path))
  print(len(os.listdir(path)))
# Out:
# 12500
# 12500

# %%
# Now lets visualise our classes 

sns.set_style('darkgrid')

x = ['cat', 'dog']
y = [dict['cat'] , dict['dog']]

sns.barplot(x,y)
plt.show()

# %%
# lets creates a function that can show the images 
def desplay_images(img_dir):
  """
  * Input  : list of image directories
  * Output : prints out the images in the list 
  """
  i = 1
  plt.figure(figsize= (10,10))
  for img in img_dir:
    plt.subplot(1,3,i)
    plt.axis(False)
    imshow(img)
    i += 1
  plt.show()

# %%
# this for loop will call the function display images. 
# we will be plotting three images from each classes

for dir in os.listdir(TRAIN_DIR):
  ipath = os.path.join(TRAIN_DIR, dir)
  count = 0
  img_dirs = []
  for i , img in enumerate( os.listdir(ipath) ):
    img_path = os.path.join(ipath, img)
    img_dirs.append(img_path)
    if i == 2:
      break
  desplay_images(img_dir = img_dirs)

# %% [markdown]
# ## Split the images between train test and validation

# %% [markdown]
# # we have created the folder called data_dir
#
#
# *   Taining data will have 70 % of data
# *   Validation and Test will have 15% of data

# %%
TRAIN_DIR = "/content/Cat Dog Data Set/train"

dirs = ['train', 'val' , 'test']

ROOT_DIR = "./data_dir"

if not os.path.exists(ROOT_DIR):
  for d in dirs:
    os.makedirs( os.path.join(ROOT_DIR, d) )

for dir in os.listdir(TRAIN_DIR):
  de = os.path.join(ROOT_DIR,"train",dir)
  os.mkdir(de)
  for img in np.random.choice( os.listdir(os.path.join(TRAIN_DIR, dir)),  int(len(os.listdir(os.path.join(TRAIN_DIR, dir)))*0.7) , replace= False ) :
    org = os.path.join(TRAIN_DIR, dir,img)
    dest = os.path.join(de,img)
    shutil.copyfile(org, dest )
    os.remove(org)
    
for dir in os.listdir(TRAIN_DIR):
  de = os.path.join(ROOT_DIR,"val",dir)
  os.mkdir(de)
  for img in np.random.choice( os.listdir(os.path.join(TRAIN_DIR, dir)),  int(len(os.listdir(os.path.join(TRAIN_DIR, dir)))*0.6) , replace= False ) :
    org = os.path.join(TRAIN_DIR, dir,img)
    dest = dest = os.path.join(de,img)

    shutil.copyfile(org, dest )
    os.remove(org)


for dir in os.listdir(TRAIN_DIR):
  de = os.path.join(ROOT_DIR,"test",dir)
  os.mkdir(de)
  for img in np.random.choice( os.listdir(os.path.join(TRAIN_DIR, dir)),  int(len(os.listdir(os.path.join(TRAIN_DIR, dir)))), replace= False ) :
    org = os.path.join(TRAIN_DIR, dir,img)
    dest = dest = os.path.join(de,img)

    shutil.copyfile(org, dest )
    os.remove(org)

# %% [markdown]
# ## Lets Now try to visualize how our data is distributed !

# %%
ROOT_DIR = "/content/data_dir"

x = []
y = []
for folder in os.listdir(ROOT_DIR):
  dict = {'cat':0 , 'dog': 0}

  class_dir = os.path.join(ROOT_DIR, folder)
  
  for cls in os.listdir(class_dir):
    images = os.path.join(class_dir,cls)
    dict[cls] = len(os.listdir(images) )


    y.append(dict[cls])
    x.append(f"{folder}_{cls}")

# %%
plt.figure(figsize=(10,5))
sns.set_style('darkgrid')
a = sns.barplot(x,y).set_title("Data Distribution")
plt.show()

# %% [markdown]
# # Using ImageDataGenerator function from keras to load and preprocess images

# %%
# we will now use keras module to pre-process our images 

traindatagen = ImageDataGenerator(
                                  rescale= 1./255,
                                  rotation_range= 0.2,
                                  zoom_range= 0.2,
                                  horizontal_flip= True,
                                  )

train_data = traindatagen.flow_from_directory(directory= "/content/data_dir/train", class_mode='binary',
                                         target_size=(224,224) )
# Out:
# Found 17500 images belonging to 2 classes.

# %%
# what number representss the class 
train_data.class_indices
# Out:
# {'cat': 0, 'dog': 1}

# %%
# reversing our dictionary for future use 

CLASS_IDX ={ j: i for i,j in train_data.class_indices.items() }
CLASS_IDX
# Out:
# {0: 'cat', 1: 'dog'}

# %%
valdatagen = ImageDataGenerator( rescale= 1./255 )

val_data = valdatagen.flow_from_directory(directory= "/content/data_dir/val", class_mode='binary',
                                         target_size=(224,224) )
# Out:
# Found 4500 images belonging to 2 classes.

# %%
testdatagen = ImageDataGenerator( rescale= 1./255 )

test_data = testdatagen.flow_from_directory(directory= "/content/data_dir/test", class_mode='binary',
                                         target_size=(224,224) )
# Out:
# Found 3000 images belonging to 2 classes.

# %% [markdown]
# # Step 3: Build Model

# %%
model = Sequential() 
model.add(Conv2D(filters=16, kernel_size= (3,3), activation= 'relu', input_shape=(224,224,3)) )

model.add(Conv2D(filters=32, kernel_size=(3,3), activation='relu' ))
model.add(MaxPool2D(pool_size=(2,2)))


model.add(Conv2D(filters=64, kernel_size=(3,3), activation='relu' ))
model.add(MaxPool2D(pool_size=(2,2)))


model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu' ))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Dropout(rate=0.25))

model.add(Flatten())
model.add(Dense(units=64, activation='relu'))
model.add(Dropout(rate=0.25))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(loss= keras.losses.binary_crossentropy, optimizer='adam', metrics=['accuracy'] )
 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 16)      448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 220, 220, 32)      4640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                5537856
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 5,635,361
# Trainable params: 5,635,361
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss= keras.losses.binary_crossentropy, optimizer='adam', metrics=['accuracy'] )

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(generator=train_data , 
                           validation_data= val_data, 
                           validation_steps= 16,
                           steps_per_epoch= 32 , 
                           epochs= 30, 
                           verbose= 1, 
                           callbacks = call_back )
# Out:
# Epoch 1/30
# 32/32 [==============================] - 57s 423ms/step - loss: 0.7221 - accuracy: 0.5197 - val_loss: 0.6825 - val_accuracy: 0.5781
#
# Epoch 00001: val_accuracy improved from -inf to 0.57812, saving model to best_model.h5
# Epoch 2/30
# 32/32 [==============================] - 13s 416ms/step - loss: 0.6854 - accuracy: 0.5422 - val_loss: 0.6821 - val_accuracy: 0.5684
#
# Epoch 00002: val_accuracy did not improve from 0.57812
# Epoch 3/30
# 32/32 [==============================] - 13s 416ms/step - loss: 0.6976 - accuracy: 0.5295 - val_loss: 0.6905 - val_accuracy: 0.5566
#
# Epoch 00003: val_accuracy did not improve from 0.57812
# Epoch 4/30
# 32/32 [==============================] - 13s 412ms/step - loss: 0.6921 - accuracy: 0.5672 - val_loss: 0.6552 - val_accuracy: 0.5898
#
# Epoch 00004: val_accuracy improved from 0.57812 to 0.58984, saving model to best_model.h5
# Epoch 5/30
# 32/32 [==============================] - 13s 421ms/step - loss: 0.6857 - accuracy: 0.5730 - val_loss: 0.6634 - val_accuracy: 0.5918
#
# Epoch 00005: val_accuracy improved from 0.58984 to 0.59180, saving model to best_model.h5
# Epoch 6/30
# 32/32 [==============================] - 13s 414ms/step - loss: 0.6717 - accuracy: 0.5978 - val_loss: 0.6620 - val_accuracy: 0.6230
#
# Epoch 00006: val_accuracy improved from 0.59180 to 0.62305, saving model to best_model.h5
# Epoch 7/30
# 32/32 [==============================] - 13s 415ms/step - loss: 0.6444 - accuracy: 0.6247 - val_loss: 0.6739 - val_accuracy: 0.5918
#
# Epoch 00007: val_accuracy did not improve from 0.62305
# Epoch 8/30
# 32/32 [==============================] - 13s 414ms/step - loss: 0.6780 - accuracy: 0.5933 - val_loss: 0.6565 - val_accuracy: 0.6055
#
# Epoch 00008: val_accuracy did not improve from 0.62305
# Epoch 9/30
# 32/32 [==============================] - 13s 411ms/step - loss: 0.6662 - accuracy: 0.6087 - val_loss: 0.6465 - val_accuracy: 0.6016
#
# Epoch 00009: val_accuracy did not improve from 0.62305
# Epoch 10/30
# 32/32 [==============================] - 13s 412ms/step - loss: 0.6204 - accuracy: 0.6633 - val_loss: 0.6485 - val_accuracy: 0.6445
#
# Epoch 00010: val_accuracy improved from 0.62305 to 0.64453, saving model to best_model.h5
# Epoch 11/30
# 32/32 [==============================] - 13s 412ms/step - loss: 0.6552 - accuracy: 0.6626 - val_loss: 0.6283 - val_accuracy: 0.6680
#
# Epoch 00011: val_accuracy improved from 0.64453 to 0.66797, saving model to best_model.h5
# Epoch 12/30
# 32/32 [==============================] - 13s 412ms/step - loss: 0.5971 - accuracy: 0.6772 - val_loss: 0.6356 - val_accuracy: 0.6367
#
# Epoch 00012: val_accuracy did not improve from 0.66797
# Epoch 13/30
# 32/32 [==============================] - 13s 413ms/step - loss: 0.6091 - accuracy: 0.6792 - val_loss: 0.6365 - val_accuracy: 0.6523
#
# Epoch 00013: val_accuracy did not improve from 0.66797
# Epoch 14/30
# 32/32 [==============================] - 13s 414ms/step - loss: 0.6006 - accuracy: 0.6851 - val_loss: 0.6018 - val_accuracy: 0.6992
#
# Epoch 00014: val_accuracy improved from 0.66797 to 0.69922, saving model to best_model.h5
# Epoch 15/30
# 32/32 [==============================] - 13s 411ms/step - loss: 0.6258 - accuracy: 0.6601 - val_loss: 0.6133 - val_accuracy: 0.6875
#
# Epoch 00015: val_accuracy did not improve from 0.69922
# Epoch 16/30
# 32/32 [==============================] - 13s 412ms/step - loss: 0.6047 - accuracy: 0.6746 - val_loss: 0.6064 - val_accuracy: 0.6719
#
# Epoch 00016: val_accuracy did not improve from 0.69922
# Epoch 17/30
# 32/32 [==============================] - 13s 414ms/step - loss: 0.5810 - accuracy: 0.7109 - val_loss: 0.5959 - val_accuracy: 0.6973
#
# Epoch 00017: val_accuracy did not improve from 0.69922
# Epoch 18/30
# 32/32 [==============================] - 13s 413ms/step - loss: 0.5930 - accuracy: 0.6867 - val_loss: 0.5702 - val_accuracy: 0.7070
#
# Epoch 00018: val_accuracy improved from 0.69922 to 0.70703, saving model to best_model.h5
# Epoch 19/30
# 32/32 [==============================] - 13s 415ms/step - loss: 0.5835 - accuracy: 0.7010 - val_loss: 0.5561 - val_accuracy: 0.7422
#
# Epoch 00019: val_accuracy improved from 0.70703 to 0.74219, saving model to best_model.h5
# Epoch 20/30
# 32/32 [==============================] - 13s 415ms/step - loss: 0.5746 - accuracy: 0.6995 - val_loss: 0.5825 - val_accuracy: 0.6797
#
# Epoch 00020: val_accuracy did not improve from 0.74219
# Epoch 21/30
# 32/32 [==============================] - 13s 414ms/step - loss: 0.6062 - accuracy: 0.6747 - val_loss: 0.5796 - val_accuracy: 0.7129
#
# Epoch 00021: val_accuracy did not improve from 0.74219
# Epoch 22/30
# 32/32 [==============================] - 13s 409ms/step - loss: 0.5704 - accuracy: 0.7202 - val_loss: 0.5703 - val_accuracy: 0.7090
#
# Epoch 00022: val_accuracy did not improve from 0.74219
# Epoch 23/30
# 32/32 [==============================] - 13s 417ms/step - loss: 0.5981 - accuracy: 0.6734 - val_loss: 0.5593 - val_accuracy: 0.7383
#
# Epoch 00023: val_accuracy did not improve from 0.74219
# Epoch 24/30
# 32/32 [==============================] - 13s 414ms/step - loss: 0.5690 - accuracy: 0.7130 - val_loss: 0.5526 - val_accuracy: 0.7266
#
# Epoch 00024: val_accuracy did not improve from 0.74219
# Epoch 00024: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model

model = load_model("/content/best_model.h5")

# %% [markdown]
# # Step 4: Model Validation

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'], c="yellow")
plt.title("val_accuracy vs accuracy")
plt.show()

# %%
plt.plot(h['loss'], c = 'red')
plt.plot(h['val_loss'] ,c="green")
plt.title("val_accuracy vs accuracy")
plt.show()

# %%
# checking out the accuracy of our model 

acc = model.evaluate_generator(generator= test_data )[1] 

print(f"The accuracy of your model is = {acc*100} %")
# Out:
# The accuracy of your model is = 70.09999752044678 %

# %% [markdown]
# ## Lets test our model by passing a unique value.
# ## Every time we run the below block of code a unique image is fetch and the model gives a predictions

# %%
TEST_DIR = "/content/Cat Dog Data Set/test"
img = np.random.choice(os.listdir(TEST_DIR), 1 )[0]
image = img_to_array(load_img( os.path.join( TEST_DIR, img), target_size=(224,224) ))/255

plt.imshow(image)
plt.title("Input Image")
plt.axis(False)
plt.show()

print("########################################################################################")

print( f"{image.shape} is the dimention of image before expansion ")
#expanding the dimension so that it can be fit inside the model
image = np.expand_dims( image, axis= 0) 
print()
print( f"{image.shape} is the dimention of image after expansion ")

print("########################################################################################")

# Now lets see what our model predicts for our image 

pred = model.predict_classes(image)
print( f" The model predicts the image is a {CLASS_IDX[pred[0][0] ]} ")
# Out:
# ########################################################################################
# (224, 224, 3) is the dimention of image before expansion
#
# (1, 224, 224, 3) is the dimention of image after expansion
# ########################################################################################
#  The model predicts the image is a cat
